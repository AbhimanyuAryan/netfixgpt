# %% [markdown]
# # WORK IN PROGRESS

# %%
from llama_index.llms.openai import OpenAI

# %%
# read .env file
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os
api_key = os.getenv("OPENAI_API_KEY")

# %%
from llama_index.core import SimpleDirectoryReader

# %%
directory_path = "butil/tmp"

# %%
input_files = [os.path.join(directory_path, f) for f in os.listdir(directory_path) if os.path.isfile(os.path.join(directory_path, f))]

# %%
input_files
# Out:
# ['butil/tmp\\12 %27O%27 Clock (film).pdf',
#  'butil/tmp\\12th Fail (film).pdf',
#  'butil/tmp\\14 Phere.pdf',
#  'butil/tmp\\1920_ Horrors of the Heart.pdf',
#  'butil/tmp\\200 %E2%80%93 Halla Ho.pdf',
#  'butil/tmp\\36 Farmhouse.pdf',
#  'butil/tmp\\420 IPC.pdf',
#  'butil/tmp\\72 Hoorain.pdf',
#  'butil/tmp\\8 A.M. Metro.pdf',
#  'butil/tmp\\83 (film).pdf',
#  'butil/tmp\\99 Songs.pdf',
#  'butil/tmp\\A Thursday.pdf',
#  'butil/tmp\\Aafat-E-Ishq.pdf',
#  'butil/tmp\\Aahana Kumra.pdf',
#  'butil/tmp\\Aamir Khan.pdf',
#  'butil/tmp\\Aankh Micholi (2023 film).pdf',
#  'butil/tmp\\Aazam.pdf',
#  'butil/tmp\\Accident or Conspiracy_ Godhra.pdf',
#  'butil/tmp\\Adhyayan Suman.pdf',
#  'butil/tmp\\Adipurush.pdf',
#  'butil/tmp\\Ae Watan Mere Watan.pdf',
#  'butil/tmp\\Afwaah.pdf',
#  'butil/tmp\\Ahaan.pdf',
#  'butil/tmp\\Ajay Wardhan.pdf',
#  'butil/tmp\\Ajeeb Daastaans.pdf',
#  'butil/tmp\\Ajmer 92.pdf',
#  'butil/tmp\\AK vs AK.pdf',
#  'butil/tmp\\Akelli.pdf',
#  'butil/tmp\\Alia Bhatt.pdf',
#  'butil/tmp\\All India Rank.pdf',
#  'butil/tmp\\Almost Pyaar with DJ Mohabbat.pdf',
#  'butil/tmp\\Alpha Beta Gamma (film).pdf',
#  'butil/tmp\\Am I Next.pdf',
#  'butil/tmp\\Amar Singh Chamkila (film).pdf',
#  'butil/tmp\\Ameena (film).pdf',
#  'butil/tmp\\Amol Parashar.pdf',
#  'butil/tmp\\An Action Hero.pdf',
#  'butil/tmp\\Anand Tiwari.pdf',
#  'butil/tmp\\Anees Bazmee.pdf',
#  'butil/tmp\\Anek.pdf',
#  'butil/tmp\\Angrezi Medium.pdf',
#  'butil/tmp\\Animal (2023 Indian film).pdf',
#  'butil/tmp\\Ankahi Kahaniya.pdf',
#  'butil/tmp\\Antim_ The Final Truth.pdf',
#  'butil/tmp\\Anup Jalota.pdf',
#  'butil/tmp\\Anurag Basu.pdf',
#  'butil/tmp\\Anwar Ka Ajab Kissa.pdf',
#  'butil/tmp\\Apurva (2023 film).pdf',
#  'butil/tmp\\Ardh.pdf',
#  'butil/tmp\\Article 370 (film).pdf',
#  'butil/tmp\\Aseq.pdf',
#  'butil/tmp\\Ateet.pdf',
#  'butil/tmp\\Atithi Bhooto Bhava.pdf',
#  'butil/tmp\\Atkan Chatkan.pdf',
#  'butil/tmp\\Atrangi Re.pdf',
#  'butil/tmp\\Attack_ Part 1.pdf',
#  'butil/tmp\\Axone (film).pdf',
#  'butil/tmp\\Baaghi 3.pdf',
#  'butil/tmp\\Babli Bouncer.pdf',
#  'butil/tmp\\Babloo Bachelor.pdf',
#  'butil/tmp\\Baby John (film).pdf',
#  'butil/tmp\\Bachchhan Paandey.pdf',
#  'butil/tmp\\Bad Boy (2023 film).pdf',
#  'butil/tmp\\Bade Miyan Chote Miyan (2024 film).pdf',
#  'butil/tmp\\Badhaai Do.pdf',
#  'butil/tmp\\Bahut Hua Samman.pdf',
#  'butil/tmp\\Bamfaad.pdf',
#  'butil/tmp\\Bansuri_ The Flute.pdf',
#  'butil/tmp\\Bastar_ The Naxal Story.pdf',
#  'butil/tmp\\Bawaal.pdf',
#  'butil/tmp\\Beautiful (2020 film).pdf',
#  'butil/tmp\\Bell Bottom (2021 film).pdf',
#  'butil/tmp\\Bengal 1947.pdf',
#  'butil/tmp\\Bhagwan Bharose.pdf',
#  'butil/tmp\\Bhaiyya Ji.pdf',
#  'butil/tmp\\Bhakshak.pdf',
#  'butil/tmp\\Bhangra Paa Le.pdf',
#  'butil/tmp\\Bhavai (film).pdf',
#  'butil/tmp\\Bhediya (film).pdf',
#  'butil/tmp\\Bheed.pdf',
#  'butil/tmp\\Bholaa.pdf',
#  'butil/tmp\\Bhonsle (film).pdf',
#  'butil/tmp\\Bhool Bhulaiyaa 2.pdf',
#  'butil/tmp\\Bhoot %E2%80%93 Part One_ The Haunted Ship.pdf',
#  'butil/tmp\\Bhoot Police.pdf',
#  'butil/tmp\\Bhuj_ The Pride of India.pdf',
#  'butil/tmp\\Blind (2023 film).pdf',
#  'butil/tmp\\Bloody Daddy.pdf',
#  'butil/tmp\\Blurr (film).pdf',
#  'butil/tmp\\Bob Biswas.pdf',
#  'butil/tmp\\Bolo Hau.pdf',
#  'butil/tmp\\Bombay Rose.pdf',
#  'butil/tmp\\Brahm%C4%81stra_ Part One %E2%80%93 Shiva.pdf',
#  'butil/tmp\\Brijendra Kala.pdf',
#  'butil/tmp\\Bulbbul.pdf',
#  'butil/tmp\\Bunty Aur Babli 2.pdf',
#  'butil/tmp\\Cargo (2019 film).pdf',
#  'butil/tmp\\Chaman Bahaar.pdf',
#  'butil/tmp\\Chandigarh Kare Aashiqui.pdf',
#  'butil/tmp\\Chandu Champion.pdf',
#  'butil/tmp\\Chatrapathi (2023 film).pdf',
#  'butil/tmp\\Chehre.pdf',
#  'butil/tmp\\Chhalaang.pdf',
#  'butil/tmp\\Chhapaak.pdf',
#  'butil/tmp\\Chhatriwali (film).pdf',
#  'butil/tmp\\Chhorii.pdf',
#  'butil/tmp\\Chintu Ka Birthday.pdf',
#  'butil/tmp\\Choked (film).pdf',
#  'butil/tmp\\Chor Nikal Ke Bhaga.pdf',
#  'butil/tmp\\Chup_ Revenge of the Artist.pdf',
#  'butil/tmp\\Cirkus (film).pdf',
#  'butil/tmp\\Class of %2783.pdf',
#  'butil/tmp\\Coat (film).pdf',
#  'butil/tmp\\Cobalt Blue (film).pdf',
#  'butil/tmp\\Code Name Abdul.pdf',
#  'butil/tmp\\Code Name_ Tiranga.pdf',
#  'butil/tmp\\Collar Bomb (2021 film).pdf',
#  'butil/tmp\\Comedy Couple.pdf',
#  'butil/tmp\\Coolie No. 1 (2020 film).pdf',
#  'butil/tmp\\Court Martial (2020 film).pdf',
#  'butil/tmp\\Crakk.pdf',
#  'butil/tmp\\Crew (film).pdf',
#  'butil/tmp\\Cuttputlli.pdf',
#  'butil/tmp\\D Company (2021 film).pdf',
#  'butil/tmp\\Dange (film).pdf',
#  'butil/tmp\\Darbaan.pdf',
#  'butil/tmp\\Darlings (film).pdf',
#  'butil/tmp\\Dashmi.pdf',
#  'butil/tmp\\Dasvi.pdf',
#  'butil/tmp\\Dedh Lakh Ka Dulha.pdf',
#  'butil/tmp\\Deepak Tijori.pdf',
#  'butil/tmp\\Deepti Naval.pdf',
#  'butil/tmp\\Dehati Disco.pdf',
#  'butil/tmp\\Deva (2024 film).pdf',
#  'butil/tmp\\Dhaakad.pdf',
#  'butil/tmp\\Dhak Dhak.pdf',
#  'butil/tmp\\Dhamaka (2021 film).pdf',
#  'butil/tmp\\Dhokha_ Round D Corner.pdf',
#  'butil/tmp\\Dial 100 (2021 film).pdf',
#  'butil/tmp\\Dibakar Banerjee.pdf',
#  'butil/tmp\\Dil Bechara.pdf',
#  'butil/tmp\\Do Ajnabee.pdf',
#  'butil/tmp\\Do Aur Do Pyaar.pdf',
#  'butil/tmp\\Dobaaraa.pdf',
#  'butil/tmp\\Doctor G.pdf',
#  'butil/tmp\\Dolly Kitty Aur Woh Chamakte Sitare.pdf',
#  'butil/tmp\\Dono (film).pdf',
#  'butil/tmp\\Doordarshan (film).pdf',
#  'butil/tmp\\Double XL.pdf',
#  'butil/tmp\\Dream Girl 2.pdf',
#  'butil/tmp\\Drishyam 2 (2022 film).pdf',
#  'butil/tmp\\Dry Day.pdf',
#  'butil/tmp\\Dukaan.pdf',
#  'butil/tmp\\Dunki (film).pdf',
#  'butil/tmp\\Durgamati.pdf',
#  'butil/tmp\\Dvand_ The Internal Conflict.pdf',
#  'butil/tmp\\Dybbuk (film).pdf',
#  'butil/tmp\\Eeb Allay Ooo!.pdf',
#  'butil/tmp\\Ek Villain Returns.pdf',
#  'butil/tmp\\Emergency (2024 film).pdf',
#  'butil/tmp\\Faactory (2021 film).pdf',
#  'butil/tmp\\Fairy Folk.pdf',
#  'butil/tmp\\Faraaz (film).pdf',
#  'butil/tmp\\Farrey.pdf',
#  'butil/tmp\\Fighter (2024 film).pdf',
#  'butil/tmp\\Flight (2021 film).pdf',
#  'butil/tmp\\Forensic (2022 film).pdf',
#  'butil/tmp\\Freddy (film).pdf',
#  'butil/tmp\\Friday Night Plan.pdf',
#  'butil/tmp\\Fukrey 3.pdf',
#  'butil/tmp\\Gadar 2.pdf',
#  'butil/tmp\\Ganapath.pdf',
#  'butil/tmp\\Gandhi Godse %E2%80%93 Ek Yudh.pdf',
#  'butil/tmp\\Gangubai Kathiawadi.pdf',
#  'butil/tmp\\Gaslight (2023 film).pdf',
#  'butil/tmp\\Gauraiya Live.pdf',
#  'butil/tmp\\Gehana Vasisth.pdf',
#  'butil/tmp\\Gehraiyaan.pdf',
#  'butil/tmp\\Ghoomer.pdf',
#  'butil/tmp\\Ghoomketu.pdf',
#  'butil/tmp\\Ghost Stories (2020 film).pdf',
#  'butil/tmp\\Ginny Weds Sunny.pdf',
#  'butil/tmp\\Goldfish (film).pdf',
#  'butil/tmp\\Good Luck Jerry.pdf',
#  'butil/tmp\\Goodbye (2022 film).pdf',
#  'butil/tmp\\Govinda Naam Mera.pdf',
#  'butil/tmp\\Guilty (2020 film).pdf',
#  'butil/tmp\\Gul Makai.pdf',
#  'butil/tmp\\Gulabo Sitabo.pdf',
#  'butil/tmp\\Gulmohar (2023 film).pdf',
#  'butil/tmp\\Gumraah (2023 film).pdf',
#  'butil/tmp\\Gunjan Saxena_ The Kargil Girl.pdf',
#  'butil/tmp\\Guns of Banaras.pdf',
#  'butil/tmp\\Guthlee Ladoo.pdf',
#  'butil/tmp\\Hacked (film).pdf',
#  'butil/tmp\\Haddi.pdf',
#  'butil/tmp\\Haemolymph (film).pdf',
#  'butil/tmp\\Hai Tujhe Salaam India.pdf',
#  'butil/tmp\\Halahal (film).pdf',
#  'butil/tmp\\Half Widow.pdf',
#  'butil/tmp\\Happy Hardy and Heer.pdf',
#  'butil/tmp\\Haseen Dillruba.pdf',
#  'butil/tmp\\Haunted Hills.pdf',
#  'butil/tmp\\Hello Charlie.pdf',
#  'butil/tmp\\Helmet (film).pdf',
#  'butil/tmp\\Heropanti 2.pdf',
#  'butil/tmp\\Himesh Reshammiya.pdf',
#  'butil/tmp\\HIT_ The First Case (2022 film).pdf',
#  'butil/tmp\\Holy Cow (film).pdf',
#  'butil/tmp\\Hukus Bukus.pdf',
#  'butil/tmp\\Hum Bhi Akele Tum Bhi Akele.pdf',
#  'butil/tmp\\Hum Do Hamare Do.pdf',
#  'butil/tmp\\Hungama 2.pdf',
#  'butil/tmp\\Hurdang.pdf',
#  'butil/tmp\\I Love You (2023 film).pdf',
#  'butil/tmp\\IB71.pdf',
#  'butil/tmp\\InCar.pdf',
#  'butil/tmp\\India Lockdown.pdf',
#  'butil/tmp\\Indoo Ki Jawani.pdf',
#  'butil/tmp\\Ishq Pashmina.pdf',
#  'butil/tmp\\Ishq-e-Nadaan.pdf',
#  'butil/tmp\\Jaadugar (2022 film).pdf',
#  'butil/tmp\\Jaane Jaan (2023 film).pdf',
#  'butil/tmp\\Jahaan Chaar Yaar.pdf',
#  'butil/tmp\\Jai Mummy Di.pdf',
#  'butil/tmp\\Jalsa (2022 film).pdf',
#  'butil/tmp\\Janhit Mein Jaari.pdf',
#  'butil/tmp\\Jawaani Jaaneman.pdf',
#  'butil/tmp\\Jawan (film).pdf',
#  'butil/tmp\\Jayeshbhai Jordaar.pdf',
#  'butil/tmp\\Jersey (2022 film).pdf',
#  'butil/tmp\\Jhund (film).pdf',
#  'butil/tmp\\Jimmy Shergill.pdf',
#  'butil/tmp\\Jogi (2022 film).pdf',
#  'butil/tmp\\Jogira Sara Ra Ra.pdf',
#  'butil/tmp\\Joram (film).pdf',
#  'butil/tmp\\Judaa Hoke Bhi.pdf',
#  'butil/tmp\\Jugjugg Jeeyo.pdf',
#  'butil/tmp\\Kaadan.pdf',
#  'butil/tmp\\Kaagaz 2.pdf',
#  'butil/tmp\\Kaagaz.pdf',
#  'butil/tmp\\Kaali Khuhi.pdf',
#  'butil/tmp\\Kaam Chalu Hai.pdf',
#  'butil/tmp\\Kaamyaab.pdf',
#  'butil/tmp\\Kaanchli Life in a Slough.pdf',
#  'butil/tmp\\Kacchey Limbu.pdf',
#  'butil/tmp\\Kadak Singh.pdf',
#  'butil/tmp\\Kadakh.pdf',
#  'butil/tmp\\Kalki 2898 AD.pdf',
#  'butil/tmp\\Kanjoos Makhichoos.pdf',
#  'butil/tmp\\Karan Patel.pdf',
#  'butil/tmp\\Kartam Bhugtam.pdf',
#  'butil/tmp\\Kathal (film).pdf',
#  'butil/tmp\\Kaun Pravin Tambe%3F.pdf',
#  'butil/tmp\\Khaali Peeli.pdf',
#  'butil/tmp\\Khichdi 2_ Mission Paanthukistan.pdf',
#  'butil/tmp\\Kho Gaye Hum Kahan.pdf',
#  'butil/tmp\\Khuda Haafiz.pdf',
#  'butil/tmp\\Khuda Haafiz_ Chapter 2 %E2%80%93 Agni Pariksha.pdf',
#  'butil/tmp\\Khufiya.pdf',
#  'butil/tmp\\Kill (film).pdf',
#  'butil/tmp\\Kisi Ka Bhai Kisi Ki Jaan.pdf',
#  'butil/tmp\\Koi Jaane Na.pdf',
#  'butil/tmp\\Kuch Khattaa Ho Jaay.pdf',
#  'butil/tmp\\Kushal Tandon.pdf',
#  'butil/tmp\\Kuttey.pdf',
#  'butil/tmp\\Kya Meri Sonam Gupta Bewafa Hai%3F.pdf',
#  'butil/tmp\\Laal Singh Chaddha.pdf',
#  'butil/tmp\\Laapataa Ladies.pdf',
#  'butil/tmp\\Ladki_ Dragon Girl.pdf',
#  'butil/tmp\\Lafzon Mein Pyaar.pdf',
#  'butil/tmp\\Lahore Confidential.pdf',
#  'butil/tmp\\Lakadbaggha.pdf',
#  'butil/tmp\\Lakeerein.pdf',
#  'butil/tmp\\Lantrani.pdf',
#  'butil/tmp\\Laxman Utekar.pdf',
#  'butil/tmp\\Laxmii.pdf',
#  'butil/tmp\\Liger (film).pdf',
#  'butil/tmp\\London Confidential.pdf',
#  'butil/tmp\\Looop Lapeta.pdf',
#  'butil/tmp\\Lootcase.pdf',
#  'butil/tmp\\Lost (2023 film).pdf',
#  'butil/tmp\\Love Aaj Kal (2020 film).pdf',
#  'butil/tmp\\Love All (2023 film).pdf',
#  'butil/tmp\\Love Hostel.pdf',
#  'butil/tmp\\Ludo (film).pdf',
#  'butil/tmp\\Lust Stories 2.pdf',
#  'butil/tmp\\Luv You Shankar.pdf',
#  'butil/tmp\\Maarrich.pdf',
#  'butil/tmp\\Maassab.pdf',
#  'butil/tmp\\Madam Chief Minister.pdf',
#  'butil/tmp\\Madgaon Express.pdf',
#  'butil/tmp\\Maidaan.pdf',
#  'butil/tmp\\Main Atal Hoon.pdf',
#  'butil/tmp\\Main Mulayam Singh Yadav.pdf',
#  'butil/tmp\\Maja Ma.pdf',
#  'butil/tmp\\Major (film).pdf',
#  'butil/tmp\\Malang (film).pdf',
#  'butil/tmp\\Mangesh Hadawale.pdf',
#  'butil/tmp\\Maska (2020 film).pdf',
#  'butil/tmp\\Mast Mein Rehne Ka.pdf',
#  'butil/tmp\\Matto Ki Saikil.pdf',
#  'butil/tmp\\Mee Raqsam.pdf',
#  'butil/tmp\\Meel Patthar.pdf',
#  'butil/tmp\\Meenakshi Sundareshwar.pdf',
#  'butil/tmp\\Mera Fauji Calling.pdf',
#  'butil/tmp\\Mere Desh Ki Dharti (film).pdf',
#  'butil/tmp\\Merry Christmas (2024 film).pdf',
#  'butil/tmp\\Middle Class Love.pdf',
#  'butil/tmp\\Mili (2022 film).pdf',
#  'butil/tmp\\Mimi (2021 Hindi film).pdf',
#  'butil/tmp\\Minus 31_ The Nagpur Files.pdf',
#  'butil/tmp\\Mission Majnu.pdf',
#  'butil/tmp\\Mission Raniganj.pdf',
#  'butil/tmp\\Mister Mummy.pdf',
#  'butil/tmp\\Mita Vasisht.pdf',
#  'butil/tmp\\Monica, O My Darling.pdf',
#  'butil/tmp\\Mr. %26 Mrs. Mahi.pdf',
#  'butil/tmp\\Mrs Undercover.pdf',
#  'butil/tmp\\Mrs. Chatterjee vs Norway.pdf',
#  'butil/tmp\\Mrs. Serial Killer.pdf',
#  'butil/tmp\\Mujib_ The Making of a Nation.pdf',
#  'butil/tmp\\Mukul Nag.pdf',
#  'butil/tmp\\Mumbai Saga.pdf',
#  'butil/tmp\\Mumbaikar (film).pdf',
#  'butil/tmp\\Murder at Teesri Manzil 302.pdf',
#  'butil/tmp\\Murder Mubarak.pdf',
#  'butil/tmp\\Music School (film).pdf',
#  'butil/tmp\\Musskan Sethi.pdf',
#  'butil/tmp\\Mystery of the Tattoo.pdf',
#  'butil/tmp\\Nail Polish (film).pdf',
#  'butil/tmp\\Namit Das.pdf',
#  'butil/tmp\\Nazar Andaaz.pdf',
#  'butil/tmp\\Neeraj Pandey.pdf',
#  'butil/tmp\\Neeyat (2023 film).pdf',
#  'butil/tmp\\Nikamma.pdf',
#  'butil/tmp\\Nipun Dharmadhikari.pdf',
#  'butil/tmp\\Nirvana Inn.pdf',
#  'butil/tmp\\Non Stop Dhamaal.pdf',
#  'butil/tmp\\O Pushpa I Hate Tears.pdf',
#  'butil/tmp\\Odd Couple (2022 film).pdf',
#  'butil/tmp\\OMG 2.pdf',
#  'butil/tmp\\One Friday Night.pdf',
#  'butil/tmp\\Operation Fryday.pdf',
#  'butil/tmp\\Operation Parindey (film).pdf',
#  'butil/tmp\\Operation Romeo (film).pdf',
#  'butil/tmp\\Operation Valentine (film).pdf',
#  'butil/tmp\\Pagglait.pdf',
#  'butil/tmp\\Pagleaazam.pdf',
#  'butil/tmp\\Panch Kriti.pdf',
#  'butil/tmp\\Panga (film).pdf',
#  'butil/tmp\\Pareeksha (2019 film).pdf',
#  'butil/tmp\\Pathaan (film).pdf',
#  'butil/tmp\\Patna Shuklla.pdf',
#  'butil/tmp\\Pepper Chicken.pdf',
#  'butil/tmp\\Phone Bhoot.pdf',
#  'butil/tmp\\Pippa (film).pdf',
#  'butil/tmp\\Plan A Plan B.pdf',
#  'butil/tmp\\Qala (film).pdf',
#  'butil/tmp\\Raaj Shaandilyaa.pdf',
#  'butil/tmp\\Raat Akeli Hai.pdf',
#  'butil/tmp\\Raat Baaki Hai.pdf',
#  'butil/tmp\\Rabia %26 Olivia.pdf',
#  'butil/tmp\\Radhe (2021 film).pdf',
#  'butil/tmp\\Radhe Shyam.pdf',
#  'butil/tmp\\Raj Kumar Gupta.pdf',
#  'butil/tmp\\Rajiv Chilaka.pdf',
#  'butil/tmp\\Rajniesh Duggall.pdf',
#  'butil/tmp\\Rajpal Yadav.pdf',
#  'butil/tmp\\Raksha Bandhan (film).pdf',
#  'butil/tmp\\Ram Setu (film).pdf',
#  'butil/tmp\\Ram Singh Charlie.pdf',
#  'butil/tmp\\Rambhajjan Zindabaad.pdf',
#  'butil/tmp\\Ramprasad Ki Tehrvi.pdf',
#  'butil/tmp\\Rashmi Rocket.pdf',
#  'butil/tmp\\Rashtra Kavach Om.pdf',
#  'butil/tmp\\Rocket Gang.pdf',
#  'butil/tmp\\Rocketry_ The Nambi Effect.pdf',
#  'butil/tmp\\Rocky Aur Rani Kii Prem Kahaani.pdf',
#  'butil/tmp\\Roohi (2021 film).pdf',
#  'butil/tmp\\Runway 34.pdf',
#  'butil/tmp\\Ruslaan Mumtaz.pdf',
#  'butil/tmp\\Ruslaan.pdf',
#  'butil/tmp\\Sab Kushal Mangal.pdf',
#  'butil/tmp\\Sadak 2.pdf',
#  'butil/tmp\\Safed (film).pdf',
#  'butil/tmp\\Saina (film).pdf',
#  'butil/tmp\\Sajini Shinde Ka Viral Video.pdf',
#  'butil/tmp\\Salaam Venky.pdf',
#  'butil/tmp\\Sam Bahadur (film).pdf',
#  'butil/tmp\\Samrat Prithviraj.pdf',
#  'butil/tmp\\Sanak.pdf',
#  'butil/tmp\\Sandeep Aur Pinky Faraar.pdf',
#  'butil/tmp\\Sardar Ka Grandson.pdf',
#  'butil/tmp\\Sardar Udham.pdf',
#  'butil/tmp\\Sarfira.pdf',
#  'butil/tmp\\Saroj Ka Rishta.pdf',
#  'butil/tmp\\Satyameva Jayate 2.pdf',
#  'butil/tmp\\Satyaprem Ki Katha.pdf',
#  'butil/tmp\\Seema Pahwa.pdf',
#  'butil/tmp\\Selfiee.pdf',
#  'butil/tmp\\Sergeant (film).pdf',
#  'butil/tmp\\Serious Men (film).pdf',
#  'butil/tmp\\Shaadisthan.pdf',
#  'butil/tmp\\Shabaash Mithu.pdf',
#  'butil/tmp\\Shaitaan (2024 film).pdf',
#  'butil/tmp\\Shakeela (film).pdf',
#  'butil/tmp\\Shakuntala Devi (film).pdf',
#  'butil/tmp\\Shamshera.pdf',
#  'butil/tmp\\Sharmaji Namkeen.pdf',
#  'butil/tmp\\Sharman Joshi.pdf',
#  'butil/tmp\\Shastry Viruddh Shastry.pdf',
#  'butil/tmp\\Shehzada (2023 film).pdf',
#  'butil/tmp\\Shemaroo Entertainment.pdf',
#  'butil/tmp\\Sherdil_ The Pilibhit Saga.pdf',
#  'butil/tmp\\Sherni (2021 film).pdf',
#  'butil/tmp\\Shershaah.pdf',
#  'butil/tmp\\Shiddat.pdf',
#  'butil/tmp\\Shikara (2020 film).pdf',
#  'butil/tmp\\Shimla Mirchi.pdf',
#  'butil/tmp\\Shiv Shastri Balboa.pdf',
#  'butil/tmp\\Shivin Narang.pdf',
#  'butil/tmp\\Shubh Mangal Zyada Saavdhan.pdf',
#  'butil/tmp\\Shukranu.pdf',
#  'butil/tmp\\Silence 2_ The Night Owl Bar Shootout.pdf',
#  'butil/tmp\\Silence... Can You Hear It%3F.pdf',
#  'butil/tmp\\Singham Again.pdf',
#  'butil/tmp\\Sir (2018 film).pdf',
#  'butil/tmp\\Sir Madam Sarpanch.pdf',
#  'butil/tmp\\Sirf Ek Bandaa Kaafi Hai.pdf',
#  'butil/tmp\\Siya (film).pdf',
#  'butil/tmp\\Skater Girl.pdf',
#  'butil/tmp\\Sky Force (film).pdf',
#  'butil/tmp\\Sooryavanshi.pdf',
#  'butil/tmp\\Squad (2021 film).pdf',
#  'butil/tmp\\Srikanth (film).pdf',
#  'butil/tmp\\Starfish (2023 film).pdf',
#  'butil/tmp\\State of Siege_ Temple Attack.pdf',
#  'butil/tmp\\Stree 2.pdf',
#  'butil/tmp\\Street Dancer 3D.pdf',
#  'butil/tmp\\Sukhee.pdf',
#  'butil/tmp\\Sulagna Panigrahi.pdf',
#  'butil/tmp\\Sumeru (film).pdf',
#  'butil/tmp\\Suraj Pe Mangal Bhari.pdf',
#  'butil/tmp\\Surendra Pal.pdf',
#  'butil/tmp\\Susant Mishra.pdf',
#  'butil/tmp\\Swatantrya Veer Savarkar.pdf',
#  'butil/tmp\\Switchh (2021 film).pdf',
#  'butil/tmp\\Tadap (2021 film).pdf',
#  'butil/tmp\\Tadka (film).pdf',
#  'butil/tmp\\Taish.pdf',
#  'butil/tmp\\Tanhaji.pdf',
#  'butil/tmp\\Tara Vs Bilal.pdf',
#  'butil/tmp\\Tarla.pdf',
#  'butil/tmp\\Tauba Tera Jalwa.pdf',
#  'butil/tmp\\Tehran (2024 film).pdf',
#  'butil/tmp\\Tejas (film).pdf',
#  'butil/tmp\\Tera Kya Hoga Lovely.pdf',
#  'butil/tmp\\Teri Baaton Mein Aisa Uljha Jiya.pdf',
#  'butil/tmp\\Thalaivii.pdf',
#  'butil/tmp\\Thank God (film).pdf',
#  'butil/tmp\\Thank You for Coming.pdf',
#  'butil/tmp\\Thappad.pdf',
#  'butil/tmp\\Thar (film).pdf',
#  'butil/tmp\\The Archies (film).pdf',
#  'butil/tmp\\The Big Bull.pdf',
#  'butil/tmp\\The Girl on the Train (2021 film).pdf',
#  'butil/tmp\\The Great Indian Family.pdf',
#  'butil/tmp\\The Hundred Bucks.pdf',
#  'butil/tmp\\The Kashmir Files.pdf',
#  'butil/tmp\\The Kerala Story.pdf',
#  'butil/tmp\\The Lady Killer (2023 film).pdf',
#  'butil/tmp\\The Pickup Artist (2019 film).pdf',
#  'butil/tmp\\The Power (2021 Indian film).pdf',
#  'butil/tmp\\The Tenant (2023 film).pdf',
#  'butil/tmp\\The Vaccine War.pdf',
#  'butil/tmp\\The Wife (2021 film).pdf',
#  'butil/tmp\\Three of Us (film).pdf',
#  'butil/tmp\\Tiger 3.pdf',
#  'butil/tmp\\Tiku Weds Sheru.pdf',
#  'butil/tmp\\Time to Dance.pdf',
#  'butil/tmp\\Toofaan.pdf',
#  'butil/tmp\\Toolsidas Junior.pdf',
#  'butil/tmp\\Torbaaz.pdf',
#  'butil/tmp\\Trahimam.pdf',
#  'butil/tmp\\Trial Period.pdf',
#  'butil/tmp\\Tribhanga (film).pdf',
#  'butil/tmp\\Tu Jhoothi Main Makkaar.pdf',
#  'butil/tmp\\Tuesdays and Fridays.pdf',
#  'butil/tmp\\Tumse Na Ho Payega (2023 film).pdf',
#  'butil/tmp\\U-Turn (2023 film).pdf',
#  'butil/tmp\\Ulajh.pdf',
#  'butil/tmp\\Unpaused.pdf',
#  'butil/tmp\\Urf Ghanta.pdf',
#  'butil/tmp\\UT69.pdf',
#  'butil/tmp\\Uunchai.pdf',
#  'butil/tmp\\Vadh (2022 film).pdf',
#  'butil/tmp\\Vedaa.pdf',
#  'butil/tmp\\Velle (film).pdf',
#  'butil/tmp\\Vikram Vedha (2022 film).pdf',
#  'butil/tmp\\Virgin Bhanupriya.pdf',
#  'butil/tmp\\Waah Zindagi.pdf',
#  'butil/tmp\\Welcome to the Jungle (2024 film).pdf',
#  'butil/tmp\\What Are the Odds.pdf',
#  'butil/tmp\\Woh Bhi Din The.pdf',
#  'butil/tmp\\Yaara.pdf',
#  'butil/tmp\\Yaariyan 2.pdf',
#  'butil/tmp\\Yaatris.pdf',
#  'butil/tmp\\Yashpal Sharma (actor).pdf',
#  'butil/tmp\\Yeh Ballet.pdf',
#  'butil/tmp\\Yodha (2024 film).pdf',
#  'butil/tmp\\Zara Hatke Zara Bachke.pdf',
#  'butil/tmp\\Zarina Wahab.pdf',
#  'butil/tmp\\Zwigato.pdf']

# %%
documents = SimpleDirectoryReader(input_files=input_files).load_data()
